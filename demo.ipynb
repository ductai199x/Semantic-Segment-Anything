# %%
from predict import *

# %%
import matplotlib.pyplot as plt

# %%
predictor = Predictor()

# %%
predictor.setup()
# Out:
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# /home/tai/1-workdir/23-semantic-segment-anything/lib/python3.9/site-packages/transformers/models/oneformer/image_processing_oneformer.py:417: FutureWarning: The `reduce_labels` argument is deprecated and will be removed in v4.27. Please use `do_reduce_labels` instead.
#   warnings.warn(

# %%
img_path = "/media/nas2/misl_image_db_edited/Blackberry Leap/1/test_010.jpg"

# %%
plt.figure(figsize=(14, 14))
plt.imshow(Image.open(img_path))

# %%
model_output = predictor.predict(img_path)
# Out:
# /home/tai/1-workdir/23-semantic-segment-anything/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#   0%|          | 0/60 [00:00<?, ?it/s]
# /home/tai/1-workdir/23-semantic-segment-anything/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
mmengine.fileio.load(model_output.json_out)
# Out:
# [{'segmentation': {'size': [1728, 3072],
# ...

# %%
plt.figure(figsize=(14, 14))
plt.imshow(Image.open(model_output.img_out))
